# %%
import quandl
import numpy as np
from mpl_finance import candlestick_ohlc
import matplotlib.pyplot as plt

# %%
# getting data and modifying it to remove gaps at weekends
r = quandl.get('WIKI/AAPL', start_date='2016-01-01', end_date='2016-03-01')
date_list = np.array(r.index.to_pydatetime())

plot_array = np.zeros([len(r), 5])
plot_array[:, 0] = np.arange(plot_array.shape[0])
plot_array[:, 1:] = r.iloc[:, :4]

# plotting candlestick chart
fig, ax = plt.subplots()
num_of_bars = 20  # the number of candlesticks to be plotted
candlestick_ohlc(ax, plot_array[-num_of_bars:], colorup='g', colordown='r')
ax.margins(x=0.0, y=0.1)
ax.yaxis.tick_right()
x_tick_labels = []
ax.set_xlim(right=plot_array[-1, 0])
ax.grid(True, color='k', ls='--', alpha=0.2)
# setting xticklabels actual dates instead of numbers
indices = np.linspace(plot_array[-num_of_bars, 0], plot_array[-1, 0], 8, dtype=int)
for i in indices:
    date_dt = date_list[i]
    date_str = date_dt.strftime('%b-%d')
    x_tick_labels.append(date_str)
ax.set(xticks=indices, xticklabels=x_tick_labels)

plt.show()
fig.savefig('plot.png')

# %%
r
# Out:
#               Open      High       Low   Close       Volume  Ex-Dividend  \
# Date
# 2016-01-04  102.61  105.3680  102.0000  105.35   67649387.0         0.00
# 2016-01-05  105.75  105.8500  102.4100  102.71   55790992.0         0.00
# 2016-01-06  100.56  102.3700   99.8700  100.70   68457388.0         0.00
# 2016-01-07   98.68  100.1300   96.4300   96.45   81094428.0         0.00
# 2016-01-08   98.55   99.1100   96.7600   96.96   70798016.0         0.00
# 2016-01-11   98.97   99.0600   97.3400   98.53   49739377.0         0.00
# 2016-01-12  100.55  100.6900   98.8399   99.96   49154227.0         0.00
# 2016-01-13  100.32  101.1900   97.3000   97.39   62439631.0         0.00
# 2016-01-14   97.96  100.4800   95.7400   99.52   63170127.0         0.00
# 2016-01-15   96.20   97.7100   95.3600   97.13   79833891.0         0.00
# 2016-01-19   98.41   98.6500   95.5000   96.66   53087747.0         0.00
# 2016-01-20   95.10   98.1897   93.4200   96.79   72334416.0         0.00
# 2016-01-21   97.06   97.8800   94.9400   96.30   52161463.0         0.00
# 2016-01-22   98.63  101.4600   98.3700  101.42   65800467.0         0.00
# 2016-01-25  101.52  101.5300   99.2100   99.44   51794525.0         0.00
# 2016-01-26   99.93  100.8800   98.0700   99.99   75077002.0         0.00
# 2016-01-27   96.04   96.6289   93.3400   93.42  133369674.0         0.00
# 2016-01-28   93.79   94.5200   92.3900   94.09   55678825.0         0.00
# 2016-01-29   94.79   97.3400   94.3500   97.34   64416504.0         0.00
# 2016-02-01   96.47   96.7100   95.4000   96.43   40943541.0         0.00
# 2016-02-02   95.42   96.0400   94.2800   94.48   37357215.0         0.00
# 2016-02-03   95.00   96.8400   94.0800   96.35   45964294.0         0.00
# 2016-02-04   95.86   97.3300   95.1900   96.60   46471652.0         0.52
# 2016-02-05   96.52   96.9200   93.6900   94.02   46418064.0         0.00
# 2016-02-08   93.13   95.7000   93.0400   95.01   54021375.0         0.00
# 2016-02-09   94.29   95.9400   93.9300   94.99   44331195.0         0.00
# 2016-02-10   95.92   96.3500   94.1000   94.27   42343601.0         0.00
# 2016-02-19          1.0   93.249550   93.987679  93.055280   93.288404
# 2016-02-22          1.0   93.550668   94.123765  93.171842   94.104338
# 2016-02-23          1.0   93.638090   93.735225  91.841093   91.977082
# 2016-02-24          1.0   91.287424   93.618663  90.646333   93.346685
# 2016-02-25          1.0   93.298118   93.987776  92.521038   93.987776
# 2016-02-26          1.0   94.415169   95.215270  93.812933   94.133478
# 2016-02-29          1.0   94.084911   95.415659  93.880927   93.919781
# 2016-03-01          1.0   94.852277   97.882887  94.628866   97.649763
#
#             Adj. Volume
# Date
# 2016-01-04   67649387.0
# 2016-01-05   55790992.0
# 2016-01-06   68457388.0
# 2016-01-07   81094428.0
# 2016-01-08   70798016.0
# 2016-01-11   49739377.0
# 2016-01-12   49154227.0
# 2016-01-13   62439631.0
# 2016-01-14   63170127.0
# 2016-01-15   79833891.0
# 2016-01-19   53087747.0
# 2016-01-20   72334416.0
# 2016-01-21   52161463.0
# 2016-01-22   65800467.0
# 2016-01-25   51794525.0
# 2016-01-26   75077002.0
# 2016-01-27  133369674.0
# 2016-01-28   55678825.0
# 2016-01-29   64416504.0
# 2016-02-01   40943541.0
# 2016-02-02   37357215.0
# 2016-02-03   45964294.0
# 2016-02-04   46471652.0
# 2016-02-05   46418064.0
# 2016-02-08   54021375.0
# 2016-02-09   44331195.0
# 2016-02-10   42343601.0
# 2016-02-11   50074711.0
# 2016-02-12   40351381.0
# 2016-02-16   49057916.0
# 2016-02-17   44863243.0
# 2016-02-18   39020983.0
# 2016-02-19   35374173.0
# 2016-02-22   34280758.0
# 2016-02-23   31942633.0
# 2016-02-24   36255745.0
# 2016-02-25   27582659.0
# 2016-02-26   28991131.0
# 2016-02-29   35216277.0
# 2016-03-01   50407147.0

# %% [markdown]
# Clustering using Base Model ---- K-Means Clustering

# %%
from pylab import plot,show
from numpy import vstack,array
from numpy.random import rand
import numpy as np
from scipy.cluster.vq import kmeans,vq
import pandas as pd
import pandas_datareader as dr
from math import sqrt
from sklearn.cluster import KMeans
from matplotlib import pyplot as plt


sp500_url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'

#read in the url and scrape ticker data
data_table = pd.read_html(sp500_url)

tickers = data_table[0][1:][0].tolist()
prices_list = []
for ticker in tickers:
    try:
        prices = dr.DataReader(ticker,'yahoo','01/01/2017')['Adj Close']
        prices = pd.DataFrame(prices)
        prices.columns = [ticker]
        prices_list.append(prices)
    except:
        pass
    prices_df = pd.concat(prices_list,axis=1)

prices_df.sort_index(inplace=True)

prices_df.head()
# Out:
#                    MMM        ABT       ABBV        ABMD         ACN  \
# Date
# 2017-01-03  163.944946  36.866280  54.853149  112.360001  110.738106
# 2017-01-04  164.193558  37.158947  55.626598  115.739998  111.004356
# 2017-01-05  163.631882  37.479931  56.048473  114.809998  109.340340
# 2017-01-06  164.110687  38.499535  56.066063  115.419998  110.585968
# 2017-01-09  163.226730  38.461781  56.435196  117.110001  109.349854
#
#                  ATVI        ADBE    AMD         AAP        AES    ...      \
# Date                                                               ...
# 2017-01-03  35.941536  103.480003  11.43  169.755737  10.266887    ...
# 2017-01-04  36.647812  104.139999  11.43  171.148819  10.178833    ...
# 2017-01-05  37.216755  105.910004  11.24  171.029388  10.046756    ...
# 2017-01-06  37.187328  108.300003  11.32  168.790543  10.407769    ...
# 2017-01-09  36.981331  108.570000  11.49  168.691055  10.152417    ...
#
#                   WRB       WYNN        XEL        XRX       XLNX        XYL  \
# Date
# 2017-01-03  42.360268  81.712685  37.324787  25.328613  55.914982  47.835201
# 2017-01-04  42.976402  84.347366  37.490185  26.284410  55.507954  48.548149
# 2017-01-05  42.766788  85.431145  37.490185  26.174128  54.835869  48.104961
# 2017-01-06  42.601643  86.356071  37.600452  25.769753  55.896046  47.767757
# 2017-01-09  41.902931  86.655045  37.030743  25.622707  55.905521  47.565422
#
#                   YUM         ZBH       ZION        ZTS
# Date
# 2017-01-03  60.062359  101.052895  40.778381  52.556099
# 2017-01-04  60.280907  101.981964  41.363899  53.066067
# 2017-01-05  60.480453  102.637207  40.693394  52.889545
# 2017-01-06  61.212101  102.646980  40.957817  53.056259
# 2017-01-09  61.383133  104.642014  40.513969  52.909161
#
# [5 rows x 502 columns]

# %%
# !pip install pandas_datareader
# Out:
# Collecting pandas_datareader
#   Downloading https://files.pythonhosted.org/packages/14/52/accb990baebe0063977f26e02df36aa7eb4015ed4e86f828cd76273cd6f1/pandas_datareader-0.8.1-py2.py3-none-any.whl (107kB)
# Requirement already satisfied: lxml in c:\users\smadh\anaconda3\lib\site-packages (from pandas_datareader) (4.2.5)
# Requirement already satisfied: requests>=2.3.0 in c:\users\smadh\anaconda3\lib\site-packages (from pandas_datareader) (2.19.1)
# Requirement already satisfied: pandas>=0.21 in c:\users\smadh\anaconda3\lib\site-packages (from pandas_datareader) (0.23.4)
# Requirement already satisfied: idna<2.8,>=2.5 in c:\users\smadh\anaconda3\lib\site-packages (from requests>=2.3.0->pandas_datareader) (2.7)
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in c:\users\smadh\anaconda3\lib\site-packages (from requests>=2.3.0->pandas_datareader) (1.23)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\smadh\anaconda3\lib\site-packages (from requests>=2.3.0->pandas_datareader) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\smadh\anaconda3\lib\site-packages (from requests>=2.3.0->pandas_datareader) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.5.0 in c:\users\smadh\anaconda3\lib\site-packages (from pandas>=0.21->pandas_datareader) (2.7.3)
# Requirement already satisfied: pytz>=2011k in c:\users\smadh\anaconda3\lib\site-packages (from pandas>=0.21->pandas_datareader) (2018.5)
# Requirement already satisfied: numpy>=1.9.0 in c:\users\smadh\anaconda3\lib\site-packages (from pandas>=0.21->pandas_datareader) (1.17.3)
# Requirement already satisfied: six>=1.5 in c:\users\smadh\anaconda3\lib\site-packages (from python-dateutil>=2.5.0->pandas>=0.21->pandas_datareader) (1.11.0)
# Installing collected packages: pandas-datareader
# Successfully installed pandas-datareader-0.8.1

# %%
#Calculate average annual percentage return and volatilities over a theoretical one year period
returns = prices_df.pct_change().mean() * 252
returns = pd.DataFrame(returns)
returns.columns = ['Returns']
returns['Volatility'] = prices_df.pct_change().std() * sqrt(252)

#format the data as a numpy array to feed into the K-Means algorithm
data = np.asarray([np.asarray(returns['Returns']),np.asarray(returns['Volatility'])]).T

X = data
distorsions = []
for k in range(2, 20):
    k_means = KMeans(n_clusters=k)
    k_means.fit(X)
    distorsions.append(k_means.inertia_)

fig = plt.figure(figsize=(15, 5))
plt.plot(range(2, 20), distorsions)
plt.grid(True)
plt.title('Elbow curve')
# Out:
# Text(0.5,1,'Elbow curve')

# %%
# computing K-Means with K = 5 (5 clusters)
centroids,_ = kmeans(data,5)
# assign each sample to a cluster
idx,_ = vq(data,centroids)

# some plotting using numpy's logical indexing
plot(data[idx==0,0],data[idx==0,1],'ob',
     data[idx==1,0],data[idx==1,1],'oy',
     data[idx==2,0],data[idx==2,1],'or',
     data[idx==3,0],data[idx==3,1],'og',
     data[idx==4,0],data[idx==4,1],'om')
plot(centroids[:,0],centroids[:,1],'sg',markersize=8)
show()

# %%
#identify the outlier
print(returns.idxmax())
# Out:
# Returns       BKR
# Volatility    BKR
# dtype: object

# %%
#drop the relevant stock from our data
returns.drop('BKR',inplace=True)

#recreate data to feed into the algorithm
data = np.asarray([np.asarray(returns['Returns']),np.asarray(returns['Volatility'])]).T

# %%
# computing K-Means with K = 5 (5 clusters)
centroids,_ = kmeans(data,5)
# assign each sample to a cluster
idx,_ = vq(data,centroids)

# some plotting using numpy's logical indexing
plot(data[idx==0,0],data[idx==0,1],'ob',
     data[idx==1,0],data[idx==1,1],'oy',
     data[idx==2,0],data[idx==2,1],'or',
     data[idx==3,0],data[idx==3,1],'og',
     data[idx==4,0],data[idx==4,1],'om')
plot(centroids[:,0],centroids[:,1],'sg',markersize=8)
show()

# %%
from collections import defaultdict
cluster_dict = defaultdict(list)
for name, cluster in zip(returns.index,idx):
    cluster_dict[cluster].append(name)

print(cluster_dict)
# Out:
# defaultdict(<class 'list'>, {1: ['MMM', 'AAP', 'ALK', 'ALXN', 'AGN', 'MO', 'AMCR', 'AIG', 'AOS', 'ADM', 'T', 'BK', 'BXP', 'BMY', 'CHRW', 'COG', 'CPB', 'CPRI', 'CAH', 'CCL', 'CNP', 'CVX', 'CTSH', 'CL', 'CMA', 'CAG', 'CVS', 'XRAY', 'FANG', 'D', 'DD', 'EMN', 'EXPE', 'XOM', 'FFIV', 'FRT', 'FDX', 'FLS', 'F', 'FOXA', 'BEN', 'FCX', 'GD', 'GIS', 'GPC', 'GILD', 'GS', 'HSIC', 'HST', 'IBM', 'INCY', 'IP', 'IPG', 'SJM', 'JCI', 'JNPR', 'K', 'KIM', 'KMI', 'KR', 'LNC', 'L', 'MTB', 'MCK', 'MET', 'NWS', 'JWN', 'NUE', 'OMC', 'PBCT', 'PM', 'PPL', 'PFG', 'PRU', 'PSA', 'REG', 'REGN', 'SEE', 'SPG', 'SLG', 'SNA', 'STT', 'SYF', 'TPR', 'TXT', 'TRV', 'ULTA', 'UPS', 'VTR', 'VNO', 'WAB', 'WBA', 'WFC', 'WRK', 'WY', 'WHR', 'WMB'], 3: ['ABT', 'ACN', 'AES', 'AFL', 'A', 'APD', 'ARE', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'AEE', 'AEP', 'AXP', 'AMT', 'AWK', 'AMP', 'AME', 'AMGN', 'APH', 'ADI', 'ANTM', 'AON', 'APTV', 'AJG', 'AIZ', 'ATO', 'ADP', 'AVY', 'BLL', 'BAC', 'BAX', 'BDX', 'BSX', 'BR', 'CAT', 'CBOE', 'CBRE', 'CE', 'CHTR', 'CHD', 'CINF', 'CSCO', 'CTXS', 'CME', 'CMS', 'KO', 'COO', 'COST', 'CCI', 'DHR', 'DRI', 'DE', 'DOV', 'DTE', 'DRE', 'ETN', 'ECL', 'ETR', 'EQIX', 'EQR', 'ESS', 'ES', 'EXC', 'EXR', 'FB', 'FAST', 'FIS', 'FE', 'FISV', 'GRMN', 'IT', 'GL', 'HCA', 'HSY', 'HLT', 'HD', 'HON', 'HUM', 'IEX', 'INFO', 'ITW', 'IR', 'INTC', 'ICE', 'IQV', 'JKHY', 'JPM', 'KSU', 'LHX', 'LDOS', 'LLY', 'LIN', 'LMT', 'LOW', 'MAR', 'MMC', 'MKC', 'MXIM', 'MCD', 'MDT', 'MRK', 'MTD', 'MAA', 'MSI', 'NDAQ', 'NEE', 'NKE', 'NSC', 'NOC', 'ORCL', 'PAYX', 'P
# %%
for each_cluster in range(5):
    print("cluster ",each_cluster)
    print("stocks ",cluster_dict[each_cluster])
# Out:
# cluster  0
# stocks  ['ABMD', 'ADBE', 'AMD', 'ALGN', 'AMZN', 'ANSS', 'AAPL', 'AMAT', 'ARNC', 'ANET', 'ADSK', 'BBY', 'BA', 'AVGO', 'CDNS', 'CDW', 'CNC', 'CMG', 'CTAS', 'CPRT', 'CSX', 'DHI', 'DG', 'EW', 'EL', 'FLT', 'FMC', 'FTNT', 'GPN', 'HFC', 'IDXX', 'ILMN', 'INTU', 'ISRG', 'IPGP', 'KEYS', 'KLAC', 'LRCX', 'LW', 'MKTX', 'MA', 'MU', 'MSFT', 'MCO', 'MSCI', 'NTAP', 'NFLX', 'NLOK', 'NRG', 'NVDA', 'NVR', 'PYPL', 'PHM', 'QRVO', 'RMD', 'SPGI', 'CRM', 'STX', 'NOW', 'SNPS', 'TTWO', 'TGT', 'TFX', 'TIF', 'TWTR', 'TDG', 'VRSN', 'VRTX', 'WCG', 'XLNX']
# cluster  1
# stocks  ['MMM', 'AAP', 'ALK', 'ALXN', 'AGN', 'MO', 'AMCR', 'AIG', 'AOS', 'ADM', 'T', 'BK', 'BXP', 'BMY', 'CHRW', 'COG', 'CPB', 'CPRI', 'CAH', 'CCL', 'CNP', 'CVX', 'CTSH', 'CL', 'CMA', 'CAG', 'CVS', 'XRAY', 'FANG', 'D', 'DD', 'EMN', 'EXPE', 'XOM', 'FFIV', 'FRT', 'FDX', 'FLS', 'F', 'FOXA', 'BEN', 'FCX', 'GD', 'GIS', 'GPC', 'GILD', 'GS', 'HSIC', 'HST', 'IBM', 'INCY', 'IP', 'IPG', 'SJM', 'JCI', 'JNPR', 'K', 'KIM', 'KMI', 'KR', 'LNC', 'L', 'MTB', 'MCK', 'MET', 'NWS', 'JWN', 'NUE', 'OMC', 'PBCT', 'PM', 'PPL', 'PFG', 'PRU', 'PSA', 'REG', 'REGN', 'SEE', 'SPG', 'SLG', 'SNA', 'STT', 'SYF', 'TPR', 'TXT', 'TRV', 'ULTA', 'UPS', 'VTR', 'VNO', 'WAB', 'WBA', 'WFC', 'WRK', 'WY', 'WHR', 'WMB']
# cluster  2
# stocks  ['ABBV', 'ATVI', 'AKAM', 'ABC', 'AIV', 'AZO', 'AVB', 'BBT', 'BIIB', 'BLK', 'BKNG', 'BWA', 'COF', 'KMX', 'CERN', 'CF', 'SCHW', 'CB', 'CI', 'C', 'CFG', 'CLX', 'CMCSA', 'COP', 'ED', 'STZ', 'GLW', 'CMI', 'DVA', 'DAL', 'DLR', 'DFS', 'DISCA', 'DISCK', 'DLTR', 'DOW', 'DUK', 'ETFC', 'EBAY', 'EIX', 'EA', 'EMR', 'EFX', 'EVRG', 'RE', 'EXPD', 'FITB', 'FRC', 'FLIR', 'FTV', 'FBHS', 'GM', 'GWW', 'HRB', 'HIG', 'HAS', 'HES', 'HPE', 'HOLX', 'HRL', 'HPQ', 'HBAN', 'HII', 'IFF', 'IRM', 'JEC', 'JBHT', 'JNJ', 'KEY', 'KMB', 'KSS', 'LH', 'LVS', 'LEG', 'LEN', 'LKQ', 'LYB', 'MPC', 'MLM', 'MAS', 'MGM', 'MCHP', 'MDLZ', 'MNST', 'MS', 'NEM', 'NWSA', 'NI', 'NTRS', 'NCLH', 'ORLY', 'OKE', 'PCAR', 'PKG', 'PH', 'PNR', 'PFE', 'PSX', 'PNW', 'PNC', 'PPG', 'PVH', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RF', 'RHI', 'ROK', 'RCL', 'SWKS', 'LUV', 'SWK', 'STI', 'SIVB', 'TMUS', 'TEL', 'TSCO', 'USB', 'UAL', 'URI', 'UTX', 'UHS', 'VLO', 'VZ', 'VMC', 'WU', 'WYNN', 'XRX', 'ZBH', 'ZION']
# cluster  3
# stocks  ['ABT', 'ACN', 'AES', 'AFL', 'A', 'APD', 'ARE', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'AEE', 'AEP', 'AXP', 'AMT', 'AWK', 'AMP', 'AME', 'AMGN', 'APH', 'ADI', 'ANTM', 'AON', 'APTV', 'AJG', 'AIZ', 'ATO', 'ADP', 'AVY', 'BLL', 'BAC', 'BAX', 'BDX', 'BSX', 'BR', 'CAT', 'CBOE', 'CBRE', 'CE', 'CHTR', 'CHD', 'CINF', 'CSCO', 'CTXS', 'CME', 'CMS', 'KO', 'COO', 'COST', 'CCI', 'DHR', 'DRI', 'DE', 'DOV', 'DTE', 'DRE', 'ETN', 'ECL', 'ETR', 'EQIX', 'EQR', 'ESS', 'ES', 'EXC', 'EXR', 'FB', 'FAST', 'FIS', 'FE', 'FISV', 'GRMN', 'IT', 'GL', 'HCA', 'HSY', 'HLT', 'HD', 'HON', 'HUM', 'IEX', 'INFO', 'ITW', 'IR', 'INTC', 'ICE', 'IQV', 'JKHY', 'JPM', 'KSU', 'LHX', 'LDOS', 'LLY', 'LIN', 'LMT', 'LOW', 'MAR', 'MMC', 'MKC', 'MXIM', 'MCD', 'MDT', 'MRK', 'MTD', 'MAA', 'MSI', 'NDAQ', 'NEE', 'NKE', 'NSC', 'NOC', 'ORCL', 'PAYX', 'PEP', 'PKI', 'PG', 'PGR', 'PLD', 'PEG', 'RTN', 'O', 'RSG', 'ROL', 'ROP', 'ROST', 'SBAC', 'SRE', 'SHW', 'SO', 'SBUX', 'SYK', 'SYY', 'TROW', 'TXN', 'TMO', 'TJX', 'TSN', 'UDR', 'UNP', 'UNH', 'VFC', 'VAR', 'VRSK', 'V', 'WMT', 'DIS', 'WM', 'WAT', 'WEC', 'WELL', 'WLTW', 'WRB', 'XEL', 'XYL', 'YUM', 'ZTS']
# cluster  4
# stocks  ['AMG', 'ALB', 'ADS', 'AAL', 'APA', 'CTL', 'XEC', 'CXO', 'CTVA', 'COTY', 'DVN', 'DISH', 'DXC', 'EOG', 'FOX', 'GPS', 'GE', 'HAL', 'HBI', 'HOG', 'PEAK', 'HP', 'IVZ', 'KHC', 'LB', 'MAC', 'M', 'MRO', 'MHK', 'TAP', 'MOS', 'MYL', 'NOV', 'NWL', 'NLSN', 'NBL', 'OXY', 'PRGO', 'PXD', 'SLB', 'FTI', 'TRIP', 'UAA', 'UA', 'UNM', 'WDC']
